# %% [markdown]
# <a href="https://colab.research.google.com/github/wangzuohao/ipynb/blob/main/LillyEarning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lilly Earnings Call Transcript
#
# Let's tie this back to finance. I have attached some text from a recent [Microsoft earnings call here](https://gist.github.com/hackingthemarkets/1c827a7750384fcf52c84594ef216a2d). Click on "raw" and save the file as a CSV. Upload it to Google Colab as microsoft-earnings.csv. Let's use what we just learned to perform a semantic search on sentences in the Microsoft earnings call. We'll start by reading the paragraphs into a pandas dataframe.

# %%
# !pip install openai -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 697.0 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 2.2 MB/s eta 0:00:00

# %%
import openai
import pandas as pd
import numpy as np
from getpass import getpass
from openai.embeddings_utils import get_embedding
from openai.embeddings_utils import cosine_similarity

openai.api_key = "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"

# %%
earnings_df = pd.read_csv('./cache.csv',encoding='utf-8')
earnings_df
# Out:
#                                                  text
# 0   度拉糖肽导致大鼠甲状腺 C 细胞肿瘤。目前尚不清楚度拉糖肽是否会引起人类甲状腺C细胞肿瘤，包...
# 1   轻度、中度或重度肾功能损害患者无需进行剂量调整（eGFR 在 15～90 ml/min/1....
# 2   在 2 型糖尿病患者中，度拉糖肽经皮下注射后，在 48 小时内达到血浆浓度峰值。2 型糖尿病...
# 3   在一项 52 周的临床试验中，在伴有中度到重度慢性肾脏疾病（eGFR [根据 CKD-EPI...
# 4   《满江红》是由张艺谋执导，沈腾、易烊千玺、张译、雷佳音、岳云鹏、王佳怡领衔主演，潘斌龙、余皑...
# ..                                                ...
# 62  注册地址：Papendorpseweg 83,3528 BJ Utrecht, The Ne...
# 63       地址：中国（上海）自由贸易试验区新灵路 118 号国际商贸大厦 19 层 1903A 室
# 64  当度拉糖肽 0.75mg 和 1.5mg 分别与磺脲类和二甲双胍联用时，有记录的症状性低血糖...
# 65  在 II 期和 III 期临床研究中，接受度拉糖肽治疗的患者中，0.5%的患者报告了全身性过...
# 66  地高辛稳态时连续使用两次度拉糖肽，地高辛的整体暴露（AUCτ）和 tmax 不变；Cmax ...
#
# [67 rows x 1 columns]

# %%
earnings_df['embedding'] = earnings_df['text'].apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
earnings_df.to_csv('cache-embeddings.csv',encoding='utf-8')

# %%
earnings_search = input("Search earnings for a sentence:")
# Out:
# Search earnings for a sentence:手机多久可以换新的

# %%
earnings_search_vector = get_embedding(earnings_search, engine="text-embedding-ada-002")
earnings_search_vector

# %%
earnings_df["similarities"] = earnings_df['embedding'].apply(lambda x: cosine_similarity(x, earnings_search_vector))
earnings_df
# Out:
#                                                  text  \
# 0   度拉糖肽导致大鼠甲状腺 C 细胞肿瘤。目前尚不清楚度拉糖肽是否会引起人类甲状腺C细胞肿瘤，包...
# 1   轻度、中度或重度肾功能损害患者无需进行剂量调整（eGFR 在 15～90 ml/min/1....
# 2   在 2 型糖尿病患者中，度拉糖肽经皮下注射后，在 48 小时内达到血浆浓度峰值。2 型糖尿病...
# 3   在一项 52 周的临床试验中，在伴有中度到重度慢性肾脏疾病（eGFR [根据 CKD-EPI...
# 4   《满江红》是由张艺谋执导，沈腾、易烊千玺、张译、雷佳音、岳云鹏、王佳怡领衔主演，潘斌龙、余皑...
# ..                                                ...
# 62  注册地址：Papendorpseweg 83,3528 BJ Utrecht, The Ne...
# 63       地址：中国（上海）自由贸易试验区新灵路 118 号国际商贸大厦 19 层 1903A 室
# 64  当度拉糖肽 0.75mg 和 1.5mg 分别与磺脲类和二甲双胍联用时，有记录的症状性低血糖...
# 65  在 II 期和 III 期临床研究中，接受度拉糖肽治疗的患者中，0.5%的患者报告了全身性过...
# 66  地高辛稳态时连续使用两次度拉糖肽，地高辛的整体暴露（AUCτ）和 tmax 不变；Cmax ...
#
#                                             embedding  similarities
# 0   [-0.003772429656237364, -0.011523178778588772,...      0.715077
# 1   [-0.0027309374418109655, -0.01117050088942051,...      0.724418
# 2   [-0.02138165757060051, -0.008141272701323032, ...      0.733628
# 3   [-0.0038853816222399473, -0.009984171018004417...      0.729383
# 4   [0.002879904815927148, -0.034377649426460266, ...      0.700073
# ..                                                ...           ...
# 62  [-0.0052066040225327015, -0.030917296186089516...      0.708635
# 63  [-0.0013566704001277685, -0.002965783467516303...      0.744591
# 64  [-0.006737089715898037, -0.016905073076486588,...      0.703055
# 65  [-0.020785577595233917, -5.925806181039661e-05...      0.707632
# 66  [-0.011356896720826626, -0.008960984647274017,...      0.729322
#
# [67 rows x 3 columns]

# %%
earnings_df.sort_values("similarities", ascending=False)
# Out:
#                                                  text  \
# 40  手机合约到期后，公司会安排手机以旧换新。原手机号码不变，更换新手机合约。 公司将统一订购通用...
# 7                      本品可在不超过 30ºC 的温度下非冷藏存储长达 14 天。
# 27  修改日期：2020 年 05 月 14 日；2020 年 09 月 02 日；2021 年 ...
# 23  若遗漏给药，如果距下一次预定给药至少为 3 天（72 小时），应尽快给药。如果距下一次预定给...
# 13  在 2 型糖尿病患者中进行的长达 6 周的临床药理学研究中，多数胃肠道不良事件报告于首次给药...
# ..                                                ...
# 64  当度拉糖肽 0.75mg 和 1.5mg 分别与磺脲类和二甲双胍联用时，有记录的症状性低血糖...
# 4   《满江红》是由张艺谋执导，沈腾、易烊千玺、张译、雷佳音、岳云鹏、王佳怡领衔主演，潘斌龙、余皑...
# 36  在临床研究中，度拉糖肽治疗期间抗度拉糖肽抗体的发生率为 1.6%，表明度拉糖肽分子中 GLP...
# 25  当度拉糖肽 1.5mg 与甘精胰岛素联用时，有记录的症状性低血糖发生率为 35.3%，比率为...
# 6   当度拉糖肽 1.5mg 与磺脲类药物联用时，有记录的症状性低血糖发生率为 11.3%，比率为...
#
#                                             embedding  similarities
# 40  [-0.0010611236793920398, -0.004517260007560253...      0.834272
# 7   [-0.00703395763412118, -0.008406756445765495, ...      0.777419
# 27  [-0.027312330901622772, -0.012698547914624214,...      0.773076
# 23  [0.0067324345000088215, 0.00036365524283610284...      0.771935
# 13  [-0.007944381795823574, -0.0036913289222866297...      0.758743
# ..                                                ...           ...
# 64  [-0.006737089715898037, -0.016905073076486588,...      0.703055
# 4   [0.002879904815927148, -0.034377649426460266, ...      0.700073
# 36  [-0.019660495221614838, 0.006504724267870188, ...      0.698597
# 25  [-0.01797814667224884, -0.01860174350440502, 0...      0.697207
# 6   [-0.013312752358615398, -0.015056168660521507,...      0.691245
#
# [67 rows x 3 columns]
