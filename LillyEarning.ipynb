# %% [markdown]
# <a href="https://colab.research.google.com/github/wangzuohao/ipynb/blob/main/LillyEarning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lilly Earnings Call Transcript
#
# Let's tie this back to finance. I have attached some text from a recent [Microsoft earnings call here](https://gist.github.com/hackingthemarkets/1c827a7750384fcf52c84594ef216a2d). Click on "raw" and save the file as a CSV. Upload it to Google Colab as microsoft-earnings.csv. Let's use what we just learned to perform a semantic search on sentences in the Microsoft earnings call. We'll start by reading the paragraphs into a pandas dataframe.

# %%
# !pip install openai -q

# %%
import openai
import pandas as pd
import numpy as np
from getpass import getpass
from openai.embeddings_utils import get_embedding
from openai.embeddings_utils import cosine_similarity

openai.api_key = "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"

# %%
earnings_df = pd.read_csv('Lilly-earnings-cn.csv',encoding='utf-8')
earnings_df
# Out:
#                                                  text
# 0   2月2日，礼来公布了2022年财报，全年总营收285.41亿美元，同比增长1%；研发投入71...
# 1   礼来目前的业务主要包括糖尿病、肿瘤、免疫、神经四大疾病领域。糖尿病业务一直是礼来具有优势且重...
# 2   作为礼来当前的王牌产品，GLP-1受体激动剂度拉糖肽增速较2021年有所下滑，不过仍以15%...
# 3   替尔泊肽是一款每周皮下注射一次的GIPR/GLP-1R双重激动剂，2022年5月首获FDA批...
# 4   不过这款新型重磅降糖药的潜力不止于此，目前正在被开发用于治疗肥胖以及合并肥胖的射血分数保留性...
# 5   在一项III期SURMOUNT-1研究中，第72周时不同剂量tirzepatide（5mg、...
# 6   肿瘤领域，CDK4/6抑制剂阿贝西利因乳腺癌辅助治疗新适应症的扩展，市场表现一路高涨，以高达...
# 7   礼来在2019年以80亿美元收购Loxo Oncology囊获的一款用于非小细胞肺癌与髓样甲...
# 8   此外，收购获得的另一款肿瘤创新药BTK C481S抑制剂pirtobrutinib刚于今年1...
# 9   Alimta（培美曲塞）、Cyramza（雷莫芦单抗）、Tyvyt（信迪利单抗）等产品虽然销...
# 10  自免也是礼来重点布局的领域，不仅有斩获多项适应症的成熟产品IL-17A单抗Taltz（依奇珠...
# 11  MNC企业对偏头痛领域一直较为重视，礼来亦是如此，目前已上市2款偏头痛药物，其中之一为Emg...
# 12  令人遗憾的是，曾被寄予厚望的阿尔兹海默病（AD）新药donanemab在今年遭遇了挫折。今年...

# %%
earnings_df['embedding'] = earnings_df['text'].apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
earnings_df.to_csv('earnings-embeddings.csv')

# %%
earnings_search = input("Search earnings for a sentence:")
# Out:
# Search earnings for a sentence:肿瘤领域有什么进展

# %%
earnings_search_vector = get_embedding(earnings_search, engine="text-embedding-ada-002")
earnings_search_vector

# %%
earnings_df["similarities"] = earnings_df['embedding'].apply(lambda x: cosine_similarity(x, earnings_search_vector))
earnings_df

# %%
earnings_df.sort_values("similarities", ascending=False)
# Out:
#                                                  text  \
# 6   肿瘤领域，CDK4/6抑制剂阿贝西利因乳腺癌辅助治疗新适应症的扩展，市场表现一路高涨，以高达...
# 8   此外，收购获得的另一款肿瘤创新药BTK C481S抑制剂pirtobrutinib刚于今年1...
# 7   礼来在2019年以80亿美元收购Loxo Oncology囊获的一款用于非小细胞肺癌与髓样甲...
# 10  自免也是礼来重点布局的领域，不仅有斩获多项适应症的成熟产品IL-17A单抗Taltz（依奇珠...
# 12  令人遗憾的是，曾被寄予厚望的阿尔兹海默病（AD）新药donanemab在今年遭遇了挫折。今年...
# 3   替尔泊肽是一款每周皮下注射一次的GIPR/GLP-1R双重激动剂，2022年5月首获FDA批...
# 5   在一项III期SURMOUNT-1研究中，第72周时不同剂量tirzepatide（5mg、...
# 1   礼来目前的业务主要包括糖尿病、肿瘤、免疫、神经四大疾病领域。糖尿病业务一直是礼来具有优势且重...
# 4   不过这款新型重磅降糖药的潜力不止于此，目前正在被开发用于治疗肥胖以及合并肥胖的射血分数保留性...
# 2   作为礼来当前的王牌产品，GLP-1受体激动剂度拉糖肽增速较2021年有所下滑，不过仍以15%...
# 9   Alimta（培美曲塞）、Cyramza（雷莫芦单抗）、Tyvyt（信迪利单抗）等产品虽然销...
# 11  MNC企业对偏头痛领域一直较为重视，礼来亦是如此，目前已上市2款偏头痛药物，其中之一为Emg...
# 0   2月2日，礼来公布了2022年财报，全年总营收285.41亿美元，同比增长1%；研发投入71...
#
#                                             embedding  similarities
# 6   [-0.020099161192774773, -0.006610133685171604,...      0.833059
# 8   [-0.03800026327371597, -0.00675713736563921, 0...      0.797889
# 7   [-0.032038792967796326, -0.00921974703669548, ...      0.796360
# 10  [-0.01668691821396351, -0.007388939615339041, ...      0.791211
# 12  [-0.020152520388364792, -0.0021475665271282196...      0.789675
# 3   [-0.027490833774209023, -0.011897805146872997,...      0.781920
# 5   [-0.028329981490969658, -0.008187936618924141,...      0.779824
# 1   [-0.0019808970391750336, -0.013228886760771275...      0.778559
# 4   [-0.030129816383123398, -0.011884691193699837,...      0.775883
# 2   [-0.01716248132288456, -0.009829298593103886, ...      0.772710
# 9   [-0.02357872761785984, -0.02251194231212139, -...      0.770434
# 11  [-0.021228766068816185, 0.006897664163261652, ...      0.761705
# 0   [-0.008886326104402542, -0.02552608586847782, ...      0.753805
